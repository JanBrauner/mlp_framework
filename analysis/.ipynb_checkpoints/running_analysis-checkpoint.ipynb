# %%
# %%javascript
# $('<div id="toc"></div>').css({position: 'fixed', top: '120px', left: 0}).appendTo(document.body);
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js');

# %%
# Execute this cell to reset the plots and reload graphing code
# %run analysis_tools_training.py
# %run analysis_tools_AD.py
# %matplotlib inline

# %% [markdown]
# # First experiments

# %% [markdown]
# CE -> Setting up -> Training with preprocessing and random  mask

# %%
experiment_name = "CE_random_patch_2_preprocessed"

show_traces(experiment_name = experiment_name, variables_to_show = ["loss"], logy=False, n = 1)
# Out:
# peak train_loss: 0.0044 in epoch: 86
# peak val_loss: 0.0031 in epoch: 82

# %%
experiment_name = "CE_central_patch_2_preprocessed"

show_traces(experiment_name = experiment_name, variables_to_show = ["train_loss", "val_loss"], logy=False, n = 1)

# %% [markdown]
# CE -> Setting up -> DTD

# %%
experiment_name = "CE_DTD_random_patch_test_1"

show_traces(experiment_name = experiment_name, variables_to_show = ["train_loss", "val_loss"], logy=False, n = 1)
# Out:
# peak train_loss: 0.0854 in epoch: 95
# peak val_loss: 0.0807 in epoch: 94

# %%
experiment_name = "CE_DTD_central_patch_test_1"

show_traces(experiment_name = experiment_name, variables_to_show = ["train_loss", "val_loss"], logy=False, n = 1)
# Out:
# Min train_loss: 0.0192 in epoch: 92
# Min val_loss: 0.1104 in epoch: 97

# %%
experiment_name = "CE_DTD_resize_test_1"

show_traces(experiment_name = experiment_name, variables_to_show = ["train_loss", "val_loss"], logy=False, n = 1)
# Out:
# Min train_loss: 0.0179 in epoch: 98
# Min val_loss: 0.1006 in epoch: 98

# %% [markdown]
# CE -> Setting up ->Mias resize

# %%
experiment_name = "CE_Mias_resize_test_1"

show_traces(experiment_name = experiment_name, variables_to_show = ["train_loss", "val_loss"], logy=False, n = 1)
# Out:
# Min train_loss: 0.0040 in epoch: 83
# Min val_loss: 0.0203 in epoch: 93

# %% [markdown]
# # r2: improvements in anomaly detection
# ## Training results
# experiments -> CE -> improvements for anomaly detection

# %%
# just show all experiments
experiment_names = [
"CE_DTD_r2_stand_scale_1",
"CE_DTD_r2_stand_scale_0p5",
"CE_DTD_r2_stand_small_mask",
"CE_DTD_r2_stand_large_context",
"CE_DTD_r2_prob_scale_1",
"CE_DTD_r2_prob_scale_0p5",
"CE_DTD_r2_prob_small_mask",
"CE_DTD_r2_prob_large_context"]

ns = [1]*8

variables_to_show = [["all"]]*4 + [["loss","map_mse_range11"]]*4

show_traces_multi_exp(experiment_names = experiment_names, ns=ns, variables_to_show=variables_to_show, logy=False)
# Out:
# peak train_loss: 0.0866 in epoch: 199
# peak val_loss: 0.0836 in epoch: 196
# ------------------------------------------------------------------
# peak train_loss: 0.1066 in epoch: 198
# peak val_loss: 0.1060 in epoch: 196
# ------------------------------------------------------------------
# peak train_loss: 0.0596 in epoch: 190
# peak val_loss: 0.0580 in epoch: 195
# ------------------------------------------------------------------
# peak train_loss: 0.0888 in epoch: 189
# peak val_loss: 0.0901 in epoch: 177
# ------------------------------------------------------------------
# peak train_loss: 4.5766 in epoch: 197
# peak val_loss: 4.5526 in epoch: 196
# peak train_map_mse_range11: 0.1769 in epoch: 194
# peak val_map_mse_range11: 0.1567 in epoch: 173
# ------------------------------------------------------------------
# peak train_loss: 4.7002 in epoch: 197
# peak val_loss: 4.6904 in epoch: 196
# peak train_map_mse_range11: 0.2298 in epoch: 197
# peak val_map_mse_range11: 0.1928 in epoch: 182
# ------------------------------------------------------------------
# peak train_loss: 4.4139 in epoch: 195
# peak val_loss: 4.3939 in epoch: 196
# peak train_map_mse_range11: 0.1351 in epoch: 185
# peak val_map_mse_range11: 0.1181 in epoch: 128
# ------------------------------------------------------------------
# peak train_loss: 4.6391 in epoch: 159
# peak val_loss: 4.6096 in epoch: 144
# peak train_map_mse_range11: 0.1974 in epoch: 157
# peak val_map_mse_range11: 0.1574 in epoch: 138
# ------------------------------------------------------------------

# %% [markdown]
# Conclusions:
# * everything is learning
# * 200 epochs is still not enough, but I might just keep it like this for this experiment
# * It's obviously easier to predict the content of the small mask, so the losses are the smallest there (talking about MSE here, so that's not small from smaller size alone, but from smaller size making prediction easier)
#     * CE-loss for the small mask is also smaller than the others, but I think that is not as relevant, because NLL should be smaller automatically for a smaller patch
# * MAP_MSE of the probabilistic model is worse than MSE of the deterministic model, but not drastically so. I think I kind of expected that, since mode of prediction (which is used for MAP) and mean (which is the value that minimizes MSE) are different.

# %% [markdown]
# ### compare the standard experiment from this round to last round

# %%
# last round
experiment_name = "CE_DTD_random_patch_test_1"
n = 1

show_traces(experiment_name = experiment_name, n=n, variables_to_show = "all", logy=False)
# Out:
# peak train_loss: 0.0854 in epoch: 95
# peak val_loss: 0.0807 in epoch: 94

# %%
# this round
experiment_name = "CE_DTD_r2_stand_scale_1"
n = 1

show_traces(experiment_name = experiment_name, n=n, variables_to_show = "all", logy=False)
# Out:
# peak train_loss: 0.0866 in epoch: 199
# peak val_loss: 0.0836 in epoch: 196

# %% [markdown]
# I don't know where this difference comes from. The only changes that happened between those two experiments are:
# * the second one is with a fixed val set
# * the second one is longer (obviously)
#
# I checked the configs again, and these were indeed the same experiment. Probably caused by random seed? I won't investigate further right now, doesn't seem crucial for my question. Especially since the images look pretty similar (see "final_report word file")

# %% [markdown]
# ## anomaly detection
# (experiments -> context encoder -> improvements for anomaly detection: anomaly detection)

# %%
experiment_names = ['CE_DTD_r2_stand_scale_1___AD_window_mean',
'CE_DTD_r2_stand_scale_1___AD_window_min',
'CE_DTD_r2_stand_scale_1___AD_window_max',
'CE_DTD_r2_stand_scale_0p5___AD_window_mean',
'CE_DTD_r2_stand_scale_0p5___AD_window_min',
'CE_DTD_r2_stand_scale_0p5___AD_window_max',
'CE_DTD_r2_stand_small_mask___AD_window_mean',
'CE_DTD_r2_stand_small_mask___AD_window_min',
'CE_DTD_r2_stand_small_mask___AD_window_max',
'CE_DTD_r2_stand_large_context___AD_window_mean',
'CE_DTD_r2_stand_large_context___AD_window_min',
'CE_DTD_r2_stand_large_context___AD_window_max',
'CE_DTD_r2_prob_scale_1___AD_window_mean',
'CE_DTD_r2_prob_scale_1___AD_window_min',
'CE_DTD_r2_prob_scale_1___AD_window_max',
'CE_DTD_r2_prob_scale_0p5___AD_window_mean',
'CE_DTD_r2_prob_scale_0p5___AD_window_min',
'CE_DTD_r2_prob_scale_0p5___AD_window_max',
'CE_DTD_r2_prob_small_mask___AD_window_mean',
'CE_DTD_r2_prob_small_mask___AD_window_min',
'CE_DTD_r2_prob_small_mask___AD_window_max',
'CE_DTD_r2_prob_large_context___AD_window_mean',
'CE_DTD_r2_prob_large_context___AD_window_min',
'CE_DTD_r2_prob_large_context___AD_window_max']

features = "r2"
sort_column = "val_mean_aucroc"

df = summary_stats(experiment_names, features, sort_column)
# Out:
#                                                 val_mean_aucroc    val_sd  \
# experiment_name
# CE_DTD_r2_prob_small_mask___AD_window_min              0.623944  0.216293
# CE_DTD_r2_prob_scale_1___AD_window_min                 0.628898  0.215582
# CE_DTD_r2_stand_small_mask___AD_window_min             0.629687  0.168971
# CE_DTD_r2_stand_large_context___AD_window_min          0.635532  0.175034
# CE_DTD_r2_prob_large_context___AD_window_min           0.642368  0.212402
# CE_DTD_r2_stand_scale_1___AD_window_min                0.646119  0.171483
# CE_DTD_r2_prob_small_mask___AD_window_mean             0.670028  0.216194
# CE_DTD_r2_stand_scale_0p5___AD_window_min              0.671811  0.178473
# CE_DTD_r2_prob_scale_0p5___AD_window_min               0.676576  0.196200
# CE_DTD_r2_stand_small_mask___AD_window_mean            0.686113  0.207889
# CE_DTD_r2_prob_small_mask___AD_window_max              0.690585  0.205885
# CE_DTD_r2_stand_small_mask___AD_window_max             0.698130  0.219646
# CE_DTD_r2_stand_scale_0p5___AD_window_max              0.700664  0.207949
# CE_DTD_r2_stand_large_context___AD_window_mean         0.701716  0.196320
# CE_DTD_r2_stand_scale_0p5___AD_window_mean             0.705256  0.195604
# CE_DTD_r2_stand_scale_1___AD_window_mean               0.709514  0.203329
# CE_DTD_r2_prob_scale_1___AD_window_mean                0.712216  0.201477
# CE_DTD_r2_stand_large_context___AD_window_max          0.716233  0.213520
# CE_DTD_r2_stand_scale_1___AD_window_max                0.717834  0.221110
# CE_DTD_r2_prob_large_context___AD_window_mean          0.722764  0.200590
# CE_DTD_r2_prob_scale_1___AD_window_max                 0.740305  0.192312
# CE_DTD_r2_prob_scale_0p5___AD_window_mean              0.743302  0.181746
# CE_DTD_r2_prob_large_context___AD_window_max           0.749941  0.192030
# CE_DTD_r2_prob_scale_0p5___AD_window_max               0.751187  0.184084
#
#                                                  val_sem  test_mean_aucroc  \
# experiment_name
# CE_DTD_r2_prob_small_mask___AD_window_min       0.009977          0.642804
# CE_DTD_r2_prob_scale_1___AD_window_min          0.009944          0.646197
# CE_DTD_r2_stand_small_mask___AD_window_min      0.007794          0.645811
# CE_DTD_r2_stand_large_context___AD_window_min   0.008074          0.645831
# CE_DTD_r2_prob_large_context___AD_window_min    0.009797          0.657870
# CE_DTD_r2_stand_scale_1___AD_window_min         0.007910          0.651267
# CE_DTD_r2_prob_small_mask___AD_window_mean      0.009972          0.684147
# CE_DTD_r2_stand_scale_0p5___AD_window_min       0.008232          0.680834
# CE_DTD_r2_prob_scale_0p5___AD_window_min        0.009050          0.692005
# CE_DTD_r2_stand_small_mask___AD_window_mean     0.009589          0.688743
# CE_DTD_r2_prob_small_mask___AD_window_max       0.009497          0.698165
# CE_DTD_r2_stand_small_mask___AD_window_max      0.010132          0.698859
# CE_DTD_r2_stand_scale_0p5___AD_window_max       0.009592          0.711456
# CE_DTD_r2_stand_large_context___AD_window_mean  0.009056          0.708395
# CE_DTD_r2_stand_scale_0p5___AD_window_mean      0.009023          0.718651
# CE_DTD_r2_stand_scale_1___AD_window_mean        0.009379          0.713632
# CE_DTD_r2_prob_scale_1___AD_window_mean         0.009293          0.728728
# CE_DTD_r2_stand_large_context___AD_window_max   0.009849          0.725275
# CE_DTD_r2_stand_scale_1___AD_window_max         0.010199          0.724519
# CE_DTD_r2_prob_large_context___AD_window_mean   0.009253          0.735547
# CE_DTD_r2_prob_scale_1___AD_window_max          0.008871          0.751122
# CE_DTD_r2_prob_scale_0p5___AD_window_mean       0.008383          0.758681
# CE_DTD_r2_prob_large_context___AD_window_max    0.008858          0.757343
# CE_DTD_r2_prob_scale_0p5___AD_window_max        0.008491          0.763600
#
#                                                  test_sd  test_sem  \
# experiment_name
# CE_DTD_r2_prob_small_mask___AD_window_min       0.215606  0.009945
# CE_DTD_r2_prob_scale_1___AD_window_min          0.215456  0.009938
# CE_DTD_r2_stand_small_mask___AD_window_min      0.165388  0.007629
# CE_DTD_r2_stand_large_context___AD_window_min   0.176810  0.008156
# CE_DTD_r2_prob_large_context___AD_window_min    0.210976  0.009732
# CE_DTD_r2_stand_scale_1___AD_window_min         0.177986  0.008210
# CE_DTD_r2_prob_small_mask___AD_window_mean      0.210748  0.009721
# CE_DTD_r2_stand_scale_0p5___AD_window_min       0.181763  0.008384
# CE_DTD_r2_prob_scale_0p5___AD_window_min        0.187388  0.008644
# CE_DTD_r2_stand_small_mask___AD_window_mean     0.203267  0.009376
# CE_DTD_r2_prob_small_mask___AD_window_max       0.197820  0.009125
# CE_DTD_r2_stand_small_mask___AD_window_max      0.212100  0.009783
# CE_DTD_r2_stand_scale_0p5___AD_window_max       0.205657  0.009486
# CE_DTD_r2_stand_large_context___AD_window_mean  0.195504  0.009018
# CE_DTD_r2_stand_scale_0p5___AD_window_mean      0.192190  0.008865
# CE_DTD_r2_stand_scale_1___AD_window_mean        0.199962  0.009224
# CE_DTD_r2_prob_scale_1___AD_window_mean         0.193112  0.008908
# CE_DTD_r2_stand_large_context___AD_window_max   0.211336  0.009748
# CE_DTD_r2_stand_scale_1___AD_window_max         0.217585  0.010036
# CE_DTD_r2_prob_large_context___AD_window_mean   0.189272  0.008730
# CE_DTD_r2_prob_scale_1___AD_window_max          0.186111  0.008585
# CE_DTD_r2_prob_scale_0p5___AD_window_mean       0.170262  0.007854
# CE_DTD_r2_prob_large_context___AD_window_max    0.186269  0.008592
# CE_DTD_r2_prob_scale_0p5___AD_window_max        0.173753  0.008015
#
#                                                AD_experiment_name  \
# experiment_name
# CE_DTD_r2_prob_small_mask___AD_window_min           AD_window_min
# CE_DTD_r2_prob_scale_1___AD_window_min              AD_window_min
# CE_DTD_r2_stand_small_mask___AD_window_min          AD_window_min
# CE_DTD_r2_stand_large_context___AD_window_min       AD_window_min
# CE_DTD_r2_prob_large_context___AD_window_min        AD_window_min
# CE_DTD_r2_stand_scale_1___AD_window_min             AD_window_min
# CE_DTD_r2_prob_small_mask___AD_window_mean         AD_window_mean
# CE_DTD_r2_stand_scale_0p5___AD_window_min           AD_window_min
# CE_DTD_r2_prob_scale_0p5___AD_window_min            AD_window_min
# CE_DTD_r2_stand_small_mask___AD_window_mean        AD_window_mean
# CE_DTD_r2_prob_small_mask___AD_window_max           AD_window_max
# CE_DTD_r2_stand_small_mask___AD_window_max          AD_window_max
# CE_DTD_r2_stand_scale_0p5___AD_window_max           AD_window_max
# CE_DTD_r2_stand_large_context___AD_window_mean     AD_window_mean
# CE_DTD_r2_stand_scale_0p5___AD_window_mean         AD_window_mean
# CE_DTD_r2_stand_scale_1___AD_window_mean           AD_window_mean
# CE_DTD_r2_prob_scale_1___AD_window_mean            AD_window_mean
# CE_DTD_r2_stand_large_context___AD_window_max       AD_window_max
# CE_DTD_r2_stand_scale_1___AD_window_max             AD_window_max
# CE_DTD_r2_prob_large_context___AD_window_mean      AD_window_mean
# CE_DTD_r2_prob_scale_1___AD_window_max              AD_window_max
# CE_DTD_r2_prob_scale_0p5___AD_window_mean          AD_window_mean
# CE_DTD_r2_prob_large_context___AD_window_max        AD_window_max
# CE_DTD_r2_prob_scale_0p5___AD_window_max            AD_window_max
#
#                                                inpainting_setting output_type  \
# experiment_name
# CE_DTD_r2_prob_small_mask___AD_window_min              small_mask        prob
# CE_DTD_r2_prob_scale_1___AD_window_min                    scale_1        prob
# CE_DTD_r2_stand_small_mask___AD_window_min             small_mask       stand
# CE_DTD_r2_stand_large_context___AD_window_min       large_context       stand
# CE_DTD_r2_prob_large_context___AD_window_min        large_context        prob
# CE_DTD_r2_stand_scale_1___AD_window_min                   scale_1       stand
# CE_DTD_r2_prob_small_mask___AD_window_mean             small_mask        prob
# CE_DTD_r2_stand_scale_0p5___AD_window_min               scale_0p5       stand
# CE_DTD_r2_prob_scale_0p5___AD_window_min                scale_0p5        prob
# CE_DTD_r2_stand_small_mask___AD_window_mean            small_mask       stand
# CE_DTD_r2_prob_small_mask___AD_window_max              small_mask        prob
# CE_DTD_r2_stand_small_mask___AD_window_max             small_mask       stand
# CE_DTD_r2_stand_scale_0p5___AD_window_max               scale_0p5       stand
# CE_DTD_r2_stand_large_context___AD_window_mean      large_context       stand
# CE_DTD_r2_stand_scale_0p5___AD_window_mean              scale_0p5       stand
# CE_DTD_r2_stand_scale_1___AD_window_mean                  scale_1       stand
# CE_DTD_r2_prob_scale_1___AD_window_mean                   scale_1        prob
# CE_DTD_r2_stand_large_context___AD_window_max       large_context       stand
# CE_DTD_r2_stand_scale_1___AD_window_max                   scale_1       stand
# CE_DTD_r2_prob_large_context___AD_window_mean       large_context        prob
# CE_DTD_r2_prob_scale_1___AD_window_max                    scale_1        prob
# CE_DTD_r2_prob_scale_0p5___AD_window_mean               scale_0p5        prob
# CE_DTD_r2_prob_large_context___AD_window_max        large_context        prob
# CE_DTD_r2_prob_scale_0p5___AD_window_max                scale_0p5        prob
#
#                                                         train_experiment_name  \
# experiment_name
# CE_DTD_r2_prob_small_mask___AD_window_min           CE_DTD_r2_prob_small_mask
# CE_DTD_r2_prob_scale_1___AD_window_min                 CE_DTD_r2_prob_scale_1
# CE_DTD_r2_stand_small_mask___AD_window_min         CE_DTD_r2_stand_small_mask
# CE_DTD_r2_stand_large_context___AD_window_min   CE_DTD_r2_stand_large_context
# CE_DTD_r2_prob_large_context___AD_window_min     CE_DTD_r2_prob_large_context
# CE_DTD_r2_stand_scale_1___AD_window_min               CE_DTD_r2_stand_scale_1
# CE_DTD_r2_prob_small_mask___AD_window_mean          CE_DTD_r2_prob_small_mask
# CE_DTD_r2_stand_scale_0p5___AD_window_min           CE_DTD_r2_stand_scale_0p5
# CE_DTD_r2_prob_scale_0p5___AD_window_min             CE_DTD_r2_prob_scale_0p5
# CE_DTD_r2_stand_small_mask___AD_window_mean        CE_DTD_r2_stand_small_mask
# CE_DTD_r2_prob_small_mask___AD_window_max           CE_DTD_r2_prob_small_mask
# CE_DTD_r2_stand_small_mask___AD_window_max         CE_DTD_r2_stand_small_mask
# CE_DTD_r2_stand_scale_0p5___AD_window_max           CE_DTD_r2_stand_scale_0p5
# CE_DTD_r2_stand_large_context___AD_window_mean  CE_DTD_r2_stand_large_context
# CE_DTD_r2_stand_scale_0p5___AD_window_mean          CE_DTD_r2_stand_scale_0p5
# CE_DTD_r2_stand_scale_1___AD_window_mean              CE_DTD_r2_stand_scale_1
# CE_DTD_r2_prob_scale_1___AD_window_mean                CE_DTD_r2_prob_scale_1
# CE_DTD_r2_stand_large_context___AD_window_max   CE_DTD_r2_stand_large_context
# CE_DTD_r2_stand_scale_1___AD_window_max               CE_DTD_r2_stand_scale_1
# CE_DTD_r2_prob_large_context___AD_window_mean    CE_DTD_r2_prob_large_context
# CE_DTD_r2_prob_scale_1___AD_window_max                 CE_DTD_r2_prob_scale_1
# CE_DTD_r2_prob_scale_0p5___AD_window_mean            CE_DTD_r2_prob_scale_0p5
# CE_DTD_r2_prob_large_context___AD_window_max     CE_DTD_r2_prob_large_context
# CE_DTD_r2_prob_scale_0p5___AD_window_max             CE_DTD_r2_prob_scale_0p5
#
#                                                window_aggregation_method
# experiment_name
# CE_DTD_r2_prob_small_mask___AD_window_min                            min
# CE_DTD_r2_prob_scale_1___AD_window_min                               min
# CE_DTD_r2_stand_small_mask___AD_window_min                           min
# CE_DTD_r2_stand_large_context___AD_window_min                        min
# CE_DTD_r2_prob_large_context___AD_window_min                         min
# CE_DTD_r2_stand_scale_1___AD_window_min                              min
# CE_DTD_r2_prob_small_mask___AD_window_mean                          mean
# CE_DTD_r2_stand_scale_0p5___AD_window_min                            min
# CE_DTD_r2_prob_scale_0p5___AD_window_min                             min
# CE_DTD_r2_stand_small_mask___AD_window_mean                         mean
# CE_DTD_r2_prob_small_mask___AD_window_max                            max
# CE_DTD_r2_stand_small_mask___AD_window_max                           max
# CE_DTD_r2_stand_scale_0p5___AD_window_max                            max
# CE_DTD_r2_stand_large_context___AD_window_mean                      mean
# CE_DTD_r2_stand_scale_0p5___AD_window_mean                          mean
# CE_DTD_r2_stand_scale_1___AD_window_mean                            mean
# CE_DTD_r2_prob_scale_1___AD_window_mean                             mean
# CE_DTD_r2_stand_large_context___AD_window_max                        max
# CE_DTD_r2_stand_scale_1___AD_window_max                              max
# CE_DTD_r2_prob_large_context___AD_window_mean                       mean
# CE_DTD_r2_prob_scale_1___AD_window_max                               max
# CE_DTD_r2_prob_scale_0p5___AD_window_mean                           mean
# CE_DTD_r2_prob_large_context___AD_window_max                         max
# CE_DTD_r2_prob_scale_0p5___AD_window_max                             max

# %% [markdown]
# ### sorted by train experiment
# So that you can compare the effect of window aggregation method

# %%
group = "train_experiment_name"
variable = "window_aggregation_method"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars



data_df = df.pivot(group, variable, y)
yerr_df = df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5))
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %%
### This was my first way to create this plot. I tnow seems overly complicated, but I'll keep it around for a while just in case 
# experiment_names = ['CE_DTD_r2_stand_scale_1___AD_window_mean',
# 'CE_DTD_r2_stand_scale_1___AD_window_min',
# 'CE_DTD_r2_stand_scale_1___AD_window_max',
# 'CE_DTD_r2_stand_scale_0p5___AD_window_mean',
# 'CE_DTD_r2_stand_scale_0p5___AD_window_min',
# 'CE_DTD_r2_stand_scale_0p5___AD_window_max',
# 'CE_DTD_r2_stand_small_mask___AD_window_mean',
# 'CE_DTD_r2_stand_small_mask___AD_window_min',
# 'CE_DTD_r2_stand_small_mask___AD_window_max',
# 'CE_DTD_r2_stand_large_context___AD_window_mean',
# 'CE_DTD_r2_stand_large_context___AD_window_min',
# 'CE_DTD_r2_stand_large_context___AD_window_max',
# 'CE_DTD_r2_prob_scale_1___AD_window_mean',
# 'CE_DTD_r2_prob_scale_1___AD_window_min',
# 'CE_DTD_r2_prob_scale_1___AD_window_max',
# 'CE_DTD_r2_prob_scale_0p5___AD_window_mean',
# 'CE_DTD_r2_prob_scale_0p5___AD_window_min',
# 'CE_DTD_r2_prob_scale_0p5___AD_window_max',
# 'CE_DTD_r2_prob_small_mask___AD_window_mean',
# 'CE_DTD_r2_prob_small_mask___AD_window_min',
# 'CE_DTD_r2_prob_small_mask___AD_window_max',
# 'CE_DTD_r2_prob_large_context___AD_window_mean',
# 'CE_DTD_r2_prob_large_context___AD_window_min',
# 'CE_DTD_r2_prob_large_context___AD_window_max']

# bar_pattern = "val_mean_aucroc" # all column names that contain this string are plotted
# err_pattern = "val_sem" #  all column names that contain this string are error bars

# df = summary_stats_by_train_exp(experiment_names)

# # plotting
# y = [column for column in df.columns if bar_pattern in column]
# yerr = [column for column in df.columns if err_pattern in column]
# df.plot(kind="bar", y=y, yerr=df[yerr].values.T, figsize=(15,5))

# %% [markdown]
# Conclusions:
#     * min always works works
#     * max nearly always works best
#
# So let's look at only mean and max, and check out patch and mask size

# %% [markdown]
# ### checking out patch and mask size:

# %%
group = "output_type"
variable = "inpainting_setting"

filter_variable = "window_aggregation_method"
filter_value = "max"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars


filtered_df = df.loc[df.loc[:,filter_variable] == filter_value,:]
data_df = filtered_df.pivot(group, variable, y)
yerr_df = filtered_df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %%
group = "output_type"
variable = "inpainting_setting"

filter_variable = "window_aggregation_method"
filter_value = "mean"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars


filtered_df = df.loc[df.loc[:,filter_variable] == filter_value,:]
data_df = filtered_df.pivot(group, variable, y)
yerr_df = filtered_df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %%
# # old version. s.a.
# y = "AD_window_mean_val_mean_aucroc"
# yerr = "AD_window_mean_val_sem"

# df.plot(kind="bar", y=y, yerr=yerr, figsize=(15,5), ylim=[0.6,1])

# %% [markdown]
# conclusion:
# * Differences are small
# * The small smask doesn't perform well
#
#
# Let's look at probabilistic vs MSE

# %% [markdown]
# ### probabilistic vs non-probabilistic

# %%
group = "inpainting_setting"
variable = "output_type"

filter_variable = "window_aggregation_method"
filter_value = "max"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars


filtered_df = df.loc[df.loc[:,filter_variable] == filter_value,:]
data_df = filtered_df.pivot(group, variable, y)
yerr_df = filtered_df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %%
group = "inpainting_setting"
variable = "output_type"

filter_variable = "window_aggregation_method"
filter_value = "mean"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars


filtered_df = df.loc[df.loc[:,filter_variable] == filter_value,:]
data_df = filtered_df.pivot(group, variable, y)
yerr_df = filtered_df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %% [markdown]
# Conclusion:
# * the probabilistic version does indeed work better, for both mean and max aggregation methods (expect for small_mask, which was the worst anyway)

# %% [markdown]
# ## combining anomaly maps from several models

# %%
experiment_names =[
'CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc05Sm_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc05Sm_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc05Sm_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc05Lc_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc05Lc_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc05Lc_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_max',
'CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_mean_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_mean_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_mean_comb_max',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_comb_min',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_comb_mean',
'CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Lc_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Lc_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Lc_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_comb_max',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_comb_min',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_comb_mean',
'CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_comb_max']


features = "r2_comb"
sort_column = "val_mean_aucroc"

df = summary_stats(experiment_names, features, sort_column)
# Out:
#                                                     val_mean_aucroc    val_sd  \
# experiment_name
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_min             0.675136  0.216449
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_min           0.679887  0.213959
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_min         0.682591  0.214532
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_min            0.688518  0.210761
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_mean_comb_min          0.689787  0.210290
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_min            0.692990  0.204821
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...         0.693378  0.208842
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_min           0.694042  0.206063
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...         0.694464  0.208773
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_min              0.695409  0.208082
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_min         0.696032  0.204151
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_min            0.697968  0.205453
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_max            0.698725  0.210858
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_mean_comb_min          0.699067  0.199299
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_mean           0.700385  0.215149
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_min          0.700538  0.207047
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_mean_comb...         0.702473  0.197705
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_max            0.703378  0.202237
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_min             0.703469  0.217034
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_min            0.703518  0.217927
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_mean_com...         0.703566  0.198499
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_mean_c...         0.704793  0.197488
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_mean           0.705325  0.205172
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_min          0.705842  0.216227
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_min           0.706357  0.210949
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_mean            0.706546  0.211748
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_max         0.707348  0.205200
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_max           0.707382  0.201782
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_min           0.708359  0.199294
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_mean          0.708377  0.208987
# ...                                                             ...       ...
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_min         0.742563  0.192201
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_mean         0.744065  0.194690
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_max           0.744823  0.190145
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean          0.744876  0.197997
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_mean_comb...         0.745110  0.191014
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_max         0.745119  0.192064
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...         0.745172  0.192070
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_max           0.745180  0.188295
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...         0.745241  0.189124
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_max          0.745602  0.186789
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_mean          ADcomb_SmLc_win_mean_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_min        ADcomb_Sc1SmLc_win_max_comb_min
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_min          ADcomb_Sc05Sm_win_max_comb_min
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_mean           ADcomb_SmLc_win_mean_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_max      ADcomb_Sc1SmLc_win_mean_comb_max
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_max          ADcomb_Sc1Lc_win_mean_comb_max
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_min          ADcomb_Sc1Lc_win_mean_comb_min
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_mean        ADcomb_Sc1Sm_win_mean_comb_mean
# ...                                                                                  ...
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_min     ADcomb_Sc1Sc05Lc_win_max_comb_min
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_mean     ADcomb_Sc1Sc05_win_mean_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_max         ADcomb_Sc05Lc_win_mean_comb_max
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean       ADcomb_Sc1SmLc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_mean_comb...    ADcomb_Sc1Sc05Lc_win_mean_comb_max
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_max     ADcomb_Sc05SmLc_win_mean_comb_max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...  ADcomb_Sc1Sc05SmLc_win_mean_comb_max
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_max         ADcomb_Sc05Sm_win_mean_comb_max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...    ADcomb_Sc1Sc05Sm_win_mean_comb_max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_max       ADcomb_Sc1Sc05_win_mean_comb_max
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_mean       ADcomb_Sc05Lc_win_mean_comb_mean
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_max               ADcomb_SmLc_win_max_comb_max
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_max         ADcomb_Sc1SmLc_win_max_comb_max
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_max             ADcomb_Sc1Lc_win_max_comb_max
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean           ADcomb_Sc1Lc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean         ADcomb_Sc05Sm_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_max           ADcomb_Sc05Sm_win_max_comb_max
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_min           ADcomb_Sc05Lc_win_max_comb_min
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_max         ADcomb_Sc1Sc05_win_max_comb_max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_max     ADcomb_Sc1Sc05Sm_win_max_comb_max
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_max           ADcomb_Sc05Lc_win_max_comb_max
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_max       ADcomb_Sc05SmLc_win_max_comb_max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...   ADcomb_Sc1Sc05SmLc_win_max_comb_max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...    ADcomb_Sc1Sc05Sm_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_max     ADcomb_Sc1Sc05Lc_win_max_comb_max
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean     ADcomb_Sc05SmLc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...  ADcomb_Sc1Sc05SmLc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean       ADcomb_Sc1Sc05_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean         ADcomb_Sc05Lc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...    ADcomb_Sc1Sc05Lc_win_max_comb_mean
#
#                                                    inpainting_setting  \
# experiment_name
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_min                   SmLc
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_min               Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_min           Sc05SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_min                 Sc1Sm
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_mean_comb_min             Sc1SmLc
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_min                  SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...          Sc1Sc05Sm
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_min                Sc1Sm
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...        Sc1Sc05SmLc
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_min                    SmLc
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_min            Sc1SmLc
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_min                Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_max                 Sc1Sm
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_mean_comb_min              Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_mean                Sc1Sm
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_min            Sc05SmLc
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_mean_comb...           Sc05SmLc
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_max                  SmLc
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_min                   SmLc
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_min                 Sc1Sm
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_mean_com...          Sc1Sc05Sm
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_mean_c...        Sc1Sc05SmLc
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_mean                 SmLc
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_min             Sc1SmLc
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_min               Sc05Sm
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_mean                  SmLc
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_max            Sc1SmLc
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_max                Sc1Lc
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_min                Sc1Lc
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_mean               Sc1Sm
# ...                                                               ...
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_min          Sc1Sc05Lc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_mean            Sc1Sc05
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_max               Sc05Lc
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean             Sc1SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_mean_comb...          Sc1Sc05Lc
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_max           Sc05SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...        Sc1Sc05SmLc
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_max               Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...          Sc1Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_max             Sc1Sc05
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_mean              Sc05Lc
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_max                    SmLc
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_max              Sc1SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_max                  Sc1Lc
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean                 Sc1Lc
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean               Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_max                Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_min                Sc05Lc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_max              Sc1Sc05
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_max          Sc1Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_max                Sc05Lc
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_max            Sc05SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...        Sc1Sc05SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...          Sc1Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_max          Sc1Sc05Lc
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean           Sc05SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...        Sc1Sc05SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean             Sc1Sc05
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean               Sc05Lc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...          Sc1Sc05Lc
#
#                                                    model_combination_method  \
# experiment_name
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_min                          min
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_min                        min
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_min                      min
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_min                         min
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_mean_comb_min                       min
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_min                         min
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...                      min
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_min                        min
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...                      min
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_min                           min
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_min                      min
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_min                         min
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_max                         max
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_mean_comb_min                       min
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_mean                       mean
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_min                       min
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_mean_comb...                      min
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_max                         max
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_min                          min
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_min                         min
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_mean_com...                      min
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_mean_c...                      min
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_mean                       mean
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_min                       min
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_min                        min
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_mean                        mean
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_max                      max
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_max                        max
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_min                        min
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_mean                      mean
# ...                                                                     ...
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_min                      min
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_mean                     mean
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_max                        max
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean                      mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_mean_comb...                      max
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_max                      max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...                      max
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_max                        max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...                      max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_max                       max
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_mean                      mean
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_max                           max
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_max                        max
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_max                          max
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean                        mean
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean                       mean
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_max                         max
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_min                         min
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_max                        max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_max                      max
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_max                         max
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_max                       max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...                      max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...                     mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_max                      max
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean                     mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...                     mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean                      mean
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean                       mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...                     mean
#
#                                                    output_type  \
# experiment_name
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_min            prob
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_min          prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_min        prob
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_min           prob
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_mean_comb_min         prob
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_min          stand
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...        prob
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_min         stand
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...        prob
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_min             prob
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_min       stand
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_min           prob
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_max           prob
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_mean_comb_min        stand
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_mean          prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_min         prob
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_mean_comb...       stand
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_max          stand
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_min           stand
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_min          stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_mean_com...       stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_mean_c...       stand
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_mean         stand
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_min        stand
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_min         stand
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_mean           prob
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_max       stand
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_max         stand
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_min         stand
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_mean        stand
# ...                                                        ...
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_min        prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_mean        prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_max          prob
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean         prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_mean_comb...        prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_max        prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...        prob
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_max          prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...        prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_max         prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_mean         prob
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_max             prob
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_max          prob
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_max            prob
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean           prob
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean          prob
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_max           prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_min           prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_max          prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_max        prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_max           prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_max         prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...        prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...        prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_max        prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean        prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...        prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean         prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean          prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...        prob
#
#                                                    train_experiment_name  \
# experiment_name
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_min            CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_min          CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_min        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_min           CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_mean_comb_min         CE_DTD_r2_prob
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_min          CE_DTD_r2_stand
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...        CE_DTD_r2_prob
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_min         CE_DTD_r2_stand
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_min             CE_DTD_r2_prob
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_min       CE_DTD_r2_stand
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_min           CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_max           CE_DTD_r2_prob
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_mean_comb_min        CE_DTD_r2_stand
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_mean          CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_min         CE_DTD_r2_prob
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_mean_comb...       CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_max          CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_min           CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_min          CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_mean_com...       CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_mean_c...       CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_mean         CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_min        CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_min         CE_DTD_r2_stand
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_mean           CE_DTD_r2_prob
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_max       CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_max         CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_min         CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_mean        CE_DTD_r2_stand
# ...                                                                  ...
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_min        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_mean        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_max          CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean         CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_mean_comb...        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_max        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_max          CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_max         CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_mean         CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_max             CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_max          CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_max            CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean           CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean          CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_max           CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_min           CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_max          CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_max        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_max           CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_max         CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_max        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean         CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean          CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...        CE_DTD_r2_prob
#
#                                                    window_aggregation_method
# experiment_name
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_min                          mean
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_min                        mean
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_min                      mean
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_min                         mean
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_mean_comb_min                       mean
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_min                         mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...                      mean
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_min                        mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...                      mean
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_min                            max
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_min                      mean
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_min                          max
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_max                         mean
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_mean_comb_min                       mean
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_mean_comb_mean                        mean
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_min                        max
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_mean_comb...                      mean
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_max                         mean
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_min                           max
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_min                          max
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_mean_com...                      mean
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_mean_c...                      mean
# CE_DTD_r2_stand___ADcomb_SmLc_win_mean_comb_mean                        mean
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_min                        max
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_min                         max
# CE_DTD_r2_prob___ADcomb_SmLc_win_mean_comb_mean                         mean
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_mean_comb_max                      mean
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_max                        mean
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_mean_comb_min                        mean
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_mean_comb_mean                       mean
# ...                                                                      ...
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_min                       max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_mean                      mean
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_max                        mean
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean                        max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_mean_comb...                      mean
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_mean_comb_max                      mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_mean_co...                      mean
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_mean_comb_max                        mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_mean_comb...                      mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_mean_comb_max                       mean
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_mean_comb_mean                       mean
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_max                            max
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_max                         max
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_max                           max
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean                          max
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean                         max
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_max                          max
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_min                          max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_max                         max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_max                       max
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_max                          max
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_max                        max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...                       max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...                       max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_max                       max
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean                       max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...                       max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean                        max
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean                         max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...                       max
#
# [132 rows x 12 columns]

# %% [markdown]
# ### effect of model combination method
# Group by output type and inpainting setting, so that you can compare the effect of window aggregation method

# %%
group = ["output_type", "inpainting_setting"] 
variable = "model_combination_method"

filter_variable = "window_aggregation_method"
filter_value = "max"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars


filtered_df = df.loc[df.loc[:,filter_variable] == filter_value,:]
data_df = filtered_df.pivot_table(index=group, columns=variable, values=y)
yerr_df = filtered_df.pivot_table(index=group, columns=variable, values=yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %% [markdown]
# Conclusions:
# if the windiw aaggregation method is max:
# * min nearly always works worst, just as for window aggregation
# * for standard output, mean always works best. For probabilistic output, except for two cases
#     * Maybe when writing the report I can write something about these two cases

# %%
group = ["output_type", "inpainting_setting"] 
variable = "model_combination_method"

filter_variable = "window_aggregation_method"
filter_value = "mean"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars


filtered_df = df.loc[df.loc[:,filter_variable] == filter_value,:]
data_df = filtered_df.pivot_table(index=group, columns=variable, values=y)
yerr_df = filtered_df.pivot_table(index=group, columns=variable, values=yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %% [markdown]
# Conclusions:
# if the window aaggregation method is mean:
# * min nearly still always works worst
# * for standard output, mean always works best. For probabilistic output, max now works best most of the time
#     * maybe write something about this if I want....
#
#
# All in all, I'm not too sure what to do with these results....
#
# Anyway, also going back to the table: clearly the best is the combination of:
# * probabilistic
# * window aggregation by max
# * model aggregation by mean

# %% [markdown]
# ### checking out patch and mask size:

# %%
group = "output_type"
variable = "inpainting_setting"

filter_variables = ["window_aggregation_method", "model_combination_method"]
filter_values = ["max", "mean"]

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars

filter_list = [df.loc[:,filter_variable] == filter_value for filter_variable, filter_value in zip(filter_variables, filter_values)]
mask = np.logical_and.reduce(filter_list)
filtered_df = df.loc[mask]
data_df = filtered_df.pivot(group, variable, y)
yerr_df = filtered_df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %% [markdown]
# That plot really doesn't tell me anything

# %%
filter_variables = ["window_aggregation_method", "model_combination_method"]
filter_values = ["max", "mean"]
filtered_df
# Out:
#                                                     val_mean_aucroc    val_sd  \
# experiment_name
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean            0.720882  0.219025
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean           0.721450  0.224934
# CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean          0.721756  0.218614
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean           0.722858  0.220726
# CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean         0.723455  0.223466
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean          0.724298  0.221762
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean         0.725065  0.222760
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb...         0.727075  0.223147
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_...         0.727855  0.221928
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb...         0.729208  0.225877
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_co...         0.729835  0.224457
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean            0.731076  0.201942
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean             0.738408  0.197997
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean          0.744876  0.197997
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean            0.751962  0.193199
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean           0.753404  0.195743
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...         0.757856  0.196301
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean         0.759799  0.195101
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...         0.760473  0.195470
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean          0.763549  0.190413
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean           0.765765  0.190895
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...         0.765874  0.192121
#
#                                                      val_sem  \
# experiment_name
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean     0.010103
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean    0.010375
# CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean   0.010084
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean    0.010181
# CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean  0.010308
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean   0.010229
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean  0.010275
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb...  0.010293
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_...  0.010237
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb...  0.010419
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_co...  0.010353
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean     0.009315
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean      0.009133
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean   0.009133
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean     0.008912
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean    0.009029
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...  0.009055
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean  0.008999
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...  0.009016
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean   0.008783
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean    0.008805
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...  0.008862
#
#                                                     test_mean_aucroc  \
# experiment_name
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean             0.727538
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean            0.726813
# CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean           0.732283
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean            0.730352
# CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean          0.733285
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean           0.734010
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean          0.731542
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb...          0.736382
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_...          0.737362
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb...          0.737878
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_co...          0.738397
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean             0.743112
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean              0.747549
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean           0.755172
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean             0.761215
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean            0.766264
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...          0.770983
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean          0.770481
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...          0.771758
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean           0.776166
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean            0.775501
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...          0.776394
#
#                                                      test_sd  test_sem  \
# experiment_name
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean     0.213815  0.009863
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean    0.219112  0.010107
# CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean   0.217541  0.010034
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean    0.217965  0.010054
# CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean  0.220510  0.010171
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean   0.216093  0.009968
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean  0.218508  0.010079
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb...  0.221172  0.010202
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_...  0.218659  0.010086
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb...  0.221757  0.010229
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_co...  0.221318  0.010209
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean     0.195637  0.009024
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean      0.193081  0.008906
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean   0.192523  0.008880
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean     0.187769  0.008661
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean    0.188416  0.008691
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...  0.189056  0.008721
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean  0.190232  0.008775
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...  0.189856  0.008757
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean   0.182692  0.008427
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean    0.184738  0.008521
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...  0.186090  0.008584
#
#                                                                       AD_experiment_name  \
# experiment_name
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean            ADcomb_SmLc_win_max_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean          ADcomb_Sc1Sm_win_max_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean        ADcomb_Sc05Lc_win_max_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean          ADcomb_Sc1Lc_win_max_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean      ADcomb_Sc1Sc05_win_max_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean        ADcomb_Sc05Sm_win_max_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean      ADcomb_Sc1SmLc_win_max_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb...    ADcomb_Sc1Sc05Lc_win_max_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_...     ADcomb_Sc05SmLc_win_max_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb...    ADcomb_Sc1Sc05Sm_win_max_comb_mean
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_co...  ADcomb_Sc1Sc05SmLc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean           ADcomb_Sc1Sm_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean             ADcomb_SmLc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean       ADcomb_Sc1SmLc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean           ADcomb_Sc1Lc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean         ADcomb_Sc05Sm_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...    ADcomb_Sc1Sc05Sm_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean     ADcomb_Sc05SmLc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...  ADcomb_Sc1Sc05SmLc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean       ADcomb_Sc1Sc05_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean         ADcomb_Sc05Lc_win_max_comb_mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...    ADcomb_Sc1Sc05Lc_win_max_comb_mean
#
#                                                    inpainting_setting  \
# experiment_name
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean                  SmLc
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean                Sc1Sm
# CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean              Sc05Lc
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean                Sc1Lc
# CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean            Sc1Sc05
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean              Sc05Sm
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean            Sc1SmLc
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb...          Sc1Sc05Lc
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_...           Sc05SmLc
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb...          Sc1Sc05Sm
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_co...        Sc1Sc05SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean                 Sc1Sm
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean                   SmLc
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean             Sc1SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean                 Sc1Lc
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean               Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...          Sc1Sc05Sm
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean           Sc05SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...        Sc1Sc05SmLc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean             Sc1Sc05
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean               Sc05Lc
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...          Sc1Sc05Lc
#
#                                                    model_combination_method  \
# experiment_name
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean                        mean
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean                       mean
# CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean                      mean
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean                       mean
# CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean                     mean
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean                      mean
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean                     mean
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb...                     mean
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_...                     mean
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb...                     mean
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_co...                     mean
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean                        mean
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean                         mean
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean                      mean
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean                        mean
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean                       mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...                     mean
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean                     mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...                     mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean                      mean
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean                       mean
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...                     mean
#
#                                                    output_type  \
# experiment_name
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean          stand
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean         stand
# CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean        stand
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean         stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean       stand
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean        stand
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean       stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb...       stand
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_...       stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb...       stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_co...       stand
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean           prob
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean            prob
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean         prob
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean           prob
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean          prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...        prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean        prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...        prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean         prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean          prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...        prob
#
#                                                    train_experiment_name  \
# experiment_name
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean          CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean         CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean        CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean         CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean       CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean        CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean       CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb...       CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_...       CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb...       CE_DTD_r2_stand
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_co...       CE_DTD_r2_stand
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean           CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean            CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean         CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean           CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean          CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...        CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean         CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean          CE_DTD_r2_prob
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...        CE_DTD_r2_prob
#
#                                                    window_aggregation_method
# experiment_name
# CE_DTD_r2_stand___ADcomb_SmLc_win_max_comb_mean                          max
# CE_DTD_r2_stand___ADcomb_Sc1Sm_win_max_comb_mean                         max
# CE_DTD_r2_stand___ADcomb_Sc05Lc_win_max_comb_mean                        max
# CE_DTD_r2_stand___ADcomb_Sc1Lc_win_max_comb_mean                         max
# CE_DTD_r2_stand___ADcomb_Sc1Sc05_win_max_comb_mean                       max
# CE_DTD_r2_stand___ADcomb_Sc05Sm_win_max_comb_mean                        max
# CE_DTD_r2_stand___ADcomb_Sc1SmLc_win_max_comb_mean                       max
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Lc_win_max_comb...                       max
# CE_DTD_r2_stand___ADcomb_Sc05SmLc_win_max_comb_...                       max
# CE_DTD_r2_stand___ADcomb_Sc1Sc05Sm_win_max_comb...                       max
# CE_DTD_r2_stand___ADcomb_Sc1Sc05SmLc_win_max_co...                       max
# CE_DTD_r2_prob___ADcomb_Sc1Sm_win_max_comb_mean                          max
# CE_DTD_r2_prob___ADcomb_SmLc_win_max_comb_mean                           max
# CE_DTD_r2_prob___ADcomb_Sc1SmLc_win_max_comb_mean                        max
# CE_DTD_r2_prob___ADcomb_Sc1Lc_win_max_comb_mean                          max
# CE_DTD_r2_prob___ADcomb_Sc05Sm_win_max_comb_mean                         max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Sm_win_max_comb_...                       max
# CE_DTD_r2_prob___ADcomb_Sc05SmLc_win_max_comb_mean                       max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05SmLc_win_max_com...                       max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05_win_max_comb_mean                        max
# CE_DTD_r2_prob___ADcomb_Sc05Lc_win_max_comb_mean                         max
# CE_DTD_r2_prob___ADcomb_Sc1Sc05Lc_win_max_comb_...                       max

# %% [markdown]
# conclusion:
# * hmm, not too much.
# * I guess the only thing that that tells me is that having Sc0.5 in the ensemble is beneficial.
#
# One thing to notice is that the test set seems to be slightly easier than the val set... can happen...

# %% [markdown]
# ### probabilistic vs non-probabilistic

# %%
group = "inpainting_setting"
variable = "output_type"

filter_variables = ["window_aggregation_method", "model_combination_method"]
filter_values = ["max", "mean"]

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars

filter_list = [df.loc[:,filter_variable] == filter_value for filter_variable, filter_value in zip(filter_variables, filter_values)]
mask = np.logical_and.reduce(filter_list)
filtered_df = df.loc[mask]
data_df = filtered_df.pivot(group, variable, y)
yerr_df = filtered_df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %% [markdown]
# Conclusion:
# * the probabilistic version does indeed work better

# %% [markdown]
# # Baselines -> Autoencoder

# %% [markdown]
# ## Training AEs

# %%
# just show all experiments
experiment_names = ["AE_DTD_r3_patch_128_bn_8192",
                    "AE_DTD_r3_patch_128_bn_4096",
                    "AE_DTD_r3_patch_128_bn_2048",
                    "AE_DTD_r3_patch_128_bn_1024",
                    "AE_DTD_r3_patch_128_bn_512",
                    "AE_DTD_r3_patch_128_bn_256",
                    "AE_DTD_r3_patch_128_bn_128",
                    "AE_DTD_r3_patch_64_bn_8192",
                    "AE_DTD_r3_patch_64_bn_4096",
                    "AE_DTD_r3_patch_64_bn_2048",
                    "AE_DTD_r3_patch_64_bn_1024",
                    "AE_DTD_r3_patch_64_bn_512",
                    "AE_DTD_r3_patch_64_bn_256",
                    "AE_DTD_r3_patch_64_bn_128",
                    "AE_DTD_r3_full_image_128_bn_8192",
                    "AE_DTD_r3_full_image_128_bn_4096",
                    "AE_DTD_r3_full_image_128_bn_2048",
                    "AE_DTD_r3_full_image_128_bn_1024",
                    "AE_DTD_r3_full_image_128_bn_512",
                    "AE_DTD_r3_full_image_128_bn_256",
                    "AE_DTD_r3_full_image_128_bn_128"]

ns = [1]*21

variables_to_show = "all" #[["all"]]*4 + [["loss","map_mse_range11"]]*4

show_traces_multi_exp(experiment_names = experiment_names, ns=ns, variables_to_show=variables_to_show, logy=False)
# Out:
# peak train_loss: 0.0516 in epoch: 175
# peak val_loss: 0.0492 in epoch: 174
# ------------------------------------------------------------------
# peak train_loss: 0.0534 in epoch: 196
# peak val_loss: 0.0502 in epoch: 175
# ------------------------------------------------------------------
# peak train_loss: 0.0560 in epoch: 199
# peak val_loss: 0.0527 in epoch: 198
# ------------------------------------------------------------------
# peak train_loss: 0.0603 in epoch: 199
# peak val_loss: 0.0551 in epoch: 199
# ------------------------------------------------------------------
# peak train_loss: 0.0666 in epoch: 187
# peak val_loss: 0.0595 in epoch: 158
# ------------------------------------------------------------------
# peak train_loss: 0.0724 in epoch: 187
# peak val_loss: 0.0657 in epoch: 173
# ------------------------------------------------------------------
# peak train_loss: 0.0795 in epoch: 198
# peak val_loss: 0.0720 in epoch: 191
# ------------------------------------------------------------------
# peak train_loss: 0.0320 in epoch: 198
# peak val_loss: 0.0295 in epoch: 192
# ------------------------------------------------------------------
# peak train_loss: 0.0336 in epoch: 191
# peak val_loss: 0.0312 in epoch: 198
# ------------------------------------------------------------------
# peak train_loss: 0.0372 in epoch: 197
# peak val_loss: 0.0347 in epoch: 193
# ------------------------------------------------------------------
# peak train_loss: 0.0402 in epoch: 187
# peak val_loss: 0.0353 in epoch: 185
# ------------------------------------------------------------------
# peak train_loss: 0.0461 in epoch: 169
# peak val_loss: 0.0425 in epoch: 196
# ------------------------------------------------------------------
# peak train_loss: 0.0499 in epoch: 187
# peak val_loss: 0.0447 in epoch: 172
# ------------------------------------------------------------------
# peak train_loss: 0.0559 in epoch: 198
# peak val_loss: 0.0506 in epoch: 192
# ------------------------------------------------------------------
# peak train_loss: 0.0337 in epoch: 199
# peak val_loss: 0.0602 in epoch: 177
# ------------------------------------------------------------------
# peak train_loss: 0.0379 in epoch: 189
# peak val_loss: 0.0626 in epoch: 194
# ------------------------------------------------------------------
# peak train_loss: 0.0396 in epoch: 195
# peak val_loss: 0.0638 in epoch: 194
# ------------------------------------------------------------------
# peak train_loss: 0.0435 in epoch: 192
# peak val_loss: 0.0672 in epoch: 190
# ------------------------------------------------------------------
# peak train_loss: 0.0493 in epoch: 188
# peak val_loss: 0.0718 in epoch: 126
# ------------------------------------------------------------------
# peak train_loss: 0.0559 in epoch: 185
# peak val_loss: 0.0758 in epoch: 37
# ------------------------------------------------------------------
# peak train_loss: 0.0597 in epoch: 197
# peak val_loss: 0.0801 in epoch: 52
# ------------------------------------------------------------------

# %%
experiment_names = ["AE_DTD_r3_patch_128_bn_8192",
                    "AE_DTD_r3_patch_128_bn_4096",
                    "AE_DTD_r3_patch_128_bn_2048",
                    "AE_DTD_r3_patch_128_bn_1024",
                    "AE_DTD_r3_patch_128_bn_512",
                    "AE_DTD_r3_patch_128_bn_256",
                    "AE_DTD_r3_patch_128_bn_128",
                    "AE_DTD_r3_patch_64_bn_8192",
                    "AE_DTD_r3_patch_64_bn_4096",
                    "AE_DTD_r3_patch_64_bn_2048",
                    "AE_DTD_r3_patch_64_bn_1024",
                    "AE_DTD_r3_patch_64_bn_512",
                    "AE_DTD_r3_patch_64_bn_256",
                    "AE_DTD_r3_patch_64_bn_128",
                    "AE_DTD_r3_full_image_128_bn_8192",
                    "AE_DTD_r3_full_image_128_bn_4096",
                    "AE_DTD_r3_full_image_128_bn_2048",
                    "AE_DTD_r3_full_image_128_bn_1024",
                    "AE_DTD_r3_full_image_128_bn_512",
                    "AE_DTD_r3_full_image_128_bn_256",
                    "AE_DTD_r3_full_image_128_bn_128"]

ns = [1]*21
print_table_peak_values(experiment_names, ns)
# Out:
#                          experiment train_loss   val_loss
# 0       AE_DTD_r3_patch_128_bn_8192  0.0516068  0.0492288
# 0       AE_DTD_r3_patch_128_bn_4096  0.0533948  0.0502432
# 0       AE_DTD_r3_patch_128_bn_2048  0.0560278  0.0527373
# 0       AE_DTD_r3_patch_128_bn_1024  0.0603027  0.0551064
# 0        AE_DTD_r3_patch_128_bn_512  0.0665506  0.0595346
# 0        AE_DTD_r3_patch_128_bn_256  0.0723773  0.0657238
# 0        AE_DTD_r3_patch_128_bn_128  0.0794583  0.0720423
# 0        AE_DTD_r3_patch_64_bn_8192  0.0320041  0.0294886
# 0        AE_DTD_r3_patch_64_bn_4096  0.0336083  0.0311588
# 0        AE_DTD_r3_patch_64_bn_2048   0.037173  0.0346504
# 0        AE_DTD_r3_patch_64_bn_1024  0.0402375  0.0353338
# 0         AE_DTD_r3_patch_64_bn_512  0.0461303  0.0425459
# 0         AE_DTD_r3_patch_64_bn_256  0.0499233   0.044656
# 0         AE_DTD_r3_patch_64_bn_128  0.0559015  0.0505856
# 0  AE_DTD_r3_full_image_128_bn_8192  0.0337336  0.0601599
# 0  AE_DTD_r3_full_image_128_bn_4096  0.0379455  0.0626495
# 0  AE_DTD_r3_full_image_128_bn_2048  0.0395855  0.0637547
# 0  AE_DTD_r3_full_image_128_bn_1024  0.0435437  0.0672101
# 0   AE_DTD_r3_full_image_128_bn_512  0.0493072  0.0718319
# 0   AE_DTD_r3_full_image_128_bn_256   0.055853  0.0757717
# 0   AE_DTD_r3_full_image_128_bn_128  0.0596911  0.0800624

# %% [markdown]
# Conclusions:
#     * all autoencoders learn, and thats what I wanted :-)
#     * let's look at a few images in the word file

# %% [markdown]
# ## Anomaly detection with AEs
# (baselines -> autoencoders -> anomaly detection)

# %%
experiment_names = [
'AE_DTD_r3_patch_128_bn_8192___AD_window_min',
'AE_DTD_r3_patch_128_bn_8192___AD_window_mean',
'AE_DTD_r3_patch_128_bn_8192___AD_window_max',
'AE_DTD_r3_patch_128_bn_4096___AD_window_min',
'AE_DTD_r3_patch_128_bn_4096___AD_window_mean',
'AE_DTD_r3_patch_128_bn_4096___AD_window_max',
'AE_DTD_r3_patch_128_bn_2048___AD_window_min',
'AE_DTD_r3_full_image_128_bn_256___AD_window_min',
'AE_DTD_r3_full_image_128_bn_256___AD_window_mean',
'AE_DTD_r3_full_image_128_bn_256___AD_window_max',
'AE_DTD_r3_full_image_128_bn_128___AD_window_min',
'AE_DTD_r3_full_image_128_bn_128___AD_window_mean',
'AE_DTD_r3_full_image_128_bn_128___AD_window_max'
]

features = "r3"
sort_column = "val_mean_aucroc"

df = summary_stats(experiment_names, features, sort_column)
# Out:
#                                                    val_mean_aucroc    val_sd  \
# experiment_name
# AE_DTD_r3_patch_64_bn_8192___AD_window_min                0.596817  0.169037
# AE_DTD_r3_patch_64_bn_2048___AD_window_min                0.608752  0.176231
# AE_DTD_r3_patch_64_bn_4096___AD_window_min                0.613225  0.168189
# AE_DTD_r3_patch_64_bn_256___AD_window_min                 0.613767  0.188948
# AE_DTD_r3_patch_64_bn_128___AD_window_min                 0.617451  0.183771
# AE_DTD_r3_patch_64_bn_512___AD_window_min                 0.618255  0.185284
# AE_DTD_r3_patch_64_bn_1024___AD_window_min                0.620754  0.179170
# AE_DTD_r3_patch_128_bn_2048___AD_window_min               0.629033  0.195423
# AE_DTD_r3_patch_64_bn_8192___AD_window_mean               0.629366  0.196232
# AE_DTD_r3_patch_64_bn_4096___AD_window_max                0.629626  0.200915
# AE_DTD_r3_patch_128_bn_8192___AD_window_min               0.629811  0.188358
# AE_DTD_r3_patch_64_bn_4096___AD_window_mean               0.630168  0.193333
# AE_DTD_r3_patch_64_bn_8192___AD_window_max                0.634818  0.202603
# AE_DTD_r3_patch_128_bn_4096___AD_window_min               0.637545  0.189076
# AE_DTD_r3_patch_64_bn_2048___AD_window_max                0.638552  0.203344
# AE_DTD_r3_patch_64_bn_2048___AD_window_mean               0.638939  0.199394
# AE_DTD_r3_patch_64_bn_256___AD_window_mean                0.642893  0.197774
# AE_DTD_r3_patch_64_bn_1024___AD_window_mean               0.646002  0.201362
# AE_DTD_r3_patch_64_bn_128___AD_window_mean                0.646334  0.194694
# AE_DTD_r3_patch_64_bn_512___AD_window_mean                0.648150  0.196854
# AE_DTD_r3_patch_64_bn_1024___AD_window_max                0.649672  0.207532
# AE_DTD_r3_patch_128_bn_8192___AD_window_mean              0.649870  0.198443
# AE_DTD_r3_patch_64_bn_512___AD_window_max                 0.651570  0.203308
# AE_DTD_r3_patch_128_bn_4096___AD_window_mean              0.653190  0.196276
# AE_DTD_r3_patch_128_bn_512___AD_window_min                0.654607  0.198176
# AE_DTD_r3_patch_128_bn_2048___AD_window_mean              0.654646  0.198853
# AE_DTD_r3_patch_64_bn_256___AD_window_max                 0.654782  0.205850
# AE_DTD_r3_patch_64_bn_128___AD_window_max                 0.658144  0.203887
# AE_DTD_r3_patch_128_bn_4096___AD_window_max               0.659561  0.203965
# AE_DTD_r3_full_image_128_bn_256___AD_window_max           0.659847  0.215697
# ...                                                            ...       ...
# AE_DTD_r3_patch_128_bn_8192___AD_window_max               0.664296  0.205005
# AE_DTD_r3_full_image_128_bn_8192___AD_window_max          0.667170  0.215476
# AE_DTD_r3_patch_64_bn_128___AD_window_min              AD_window_min
# AE_DTD_r3_patch_64_bn_512___AD_window_min              AD_window_min
# AE_DTD_r3_patch_64_bn_1024___AD_window_min             AD_window_min
# AE_DTD_r3_patch_128_bn_2048___AD_window_min            AD_window_min
# AE_DTD_r3_patch_64_bn_8192___AD_window_mean           AD_window_mean
# AE_DTD_r3_patch_64_bn_4096___AD_window_max             AD_window_max
# AE_DTD_r3_patch_128_bn_8192___AD_window_min            AD_window_min
# AE_DTD_r3_patch_64_bn_4096___AD_window_mean           AD_window_mean
# AE_DTD_r3_patch_64_bn_8192___AD_window_max             AD_window_max
# AE_DTD_r3_patch_128_bn_4096___AD_window_min            AD_window_min
# AE_DTD_r3_patch_64_bn_2048___AD_window_max             AD_window_max
# AE_DTD_r3_patch_64_bn_2048___AD_window_mean           AD_window_mean
# AE_DTD_r3_patch_64_bn_256___AD_window_mean            AD_window_mean
# AE_DTD_r3_patch_64_bn_1024___AD_window_mean           AD_window_mean
# AE_DTD_r3_patch_64_bn_128___AD_window_mean            AD_window_mean
# AE_DTD_r3_patch_64_bn_512___AD_window_mean            AD_window_mean
# AE_DTD_r3_patch_64_bn_1024___AD_window_max             AD_window_max
# AE_DTD_r3_patch_128_bn_8192___AD_window_mean          AD_window_mean
# AE_DTD_r3_patch_64_bn_512___AD_window_max              AD_window_max
# AE_DTD_r3_patch_128_bn_4096___AD_window_mean          AD_window_mean
# AE_DTD_r3_patch_128_bn_512___AD_window_min             AD_window_min
# AE_DTD_r3_patch_128_bn_2048___AD_window_mean          AD_window_mean
# AE_DTD_r3_patch_64_bn_256___AD_window_max              AD_window_max
# AE_DTD_r3_patch_64_bn_128___AD_window_max              AD_window_max
# AE_DTD_r3_patch_128_bn_4096___AD_window_max            AD_window_max
# AE_DTD_r3_full_image_128_bn_256___AD_window_max        AD_window_max
# ...                                                              ...
# AE_DTD_r3_patch_128_bn_8192___AD_window_max            AD_window_max
# AE_DTD_r3_full_image_128_bn_8192___AD_window_max       AD_window_max
# AE_DTD_r3_patch_128_bn_1024___AD_window_max            AD_window_max
# AE_DTD_r3_full_image_128_bn_512___AD_window_max        AD_window_max
# AE_DTD_r3_full_image_128_bn_128___AD_window_max        AD_window_max
# AE_DTD_r3_patch_128_bn_512___AD_window_mean           AD_window_mean
# AE_DTD_r3_full_image_128_bn_4096___AD_window_max       AD_window_max
# AE_DTD_r3_full_image_128_bn_2048___AD_window_max       AD_window_max
# AE_DTD_r3_full_image_128_bn_8192___AD_window_min       AD_window_min
# AE_DTD_r3_patch_128_bn_1024___AD_window_mean          AD_window_mean
# AE_DTD_r3_full_image_128_bn_4096___AD_window_min       AD_window_min
# AE_DTD_r3_full_image_128_bn_1024___AD_window_max       AD_window_max
# AE_DTD_r3_full_image_128_bn_2048___AD_window_min       AD_window_min
# AE_DTD_r3_patch_128_bn_512___AD_window_max             AD_window_max
# AE_DTD_r3_full_image_128_bn_256___AD_window_min        AD_window_min
# AE_DTD_r3_patch_128_bn_256___AD_window_mean           AD_window_mean
# AE_DTD_r3_full_image_128_bn_512___AD_window_min        AD_window_min
# AE_DTD_r3_patch_128_bn_128___AD_window_min             AD_window_min
# AE_DTD_r3_full_image_128_bn_128___AD_window_min        AD_window_min
# AE_DTD_r3_patch_128_bn_128___AD_window_max             AD_window_max
# AE_DTD_r3_patch_128_bn_256___AD_window_max             AD_window_max
# AE_DTD_r3_full_image_128_bn_256___AD_window_mean      AD_window_mean
# AE_DTD_r3_full_image_128_bn_8192___AD_window_mean     AD_window_mean
# AE_DTD_r3_patch_128_bn_128___AD_window_mean           AD_window_mean
# AE_DTD_r3_full_image_128_bn_1024___AD_window_min       AD_window_min
# AE_DTD_r3_full_image_128_bn_4096___AD_window_mean     AD_window_mean
# AE_DTD_r3_full_image_128_bn_2048___AD_window_mean     AD_window_mean
# AE_DTD_r3_full_image_128_bn_128___AD_window_mean      AD_window_mean
# AE_DTD_r3_full_image_128_bn_512___AD_window_mean      AD_window_mean
# AE_DTD_r3_full_image_128_bn_1024___AD_window_mean     AD_window_mean
#
#                                                   autoencoding_setting  \
# experiment_name
# AE_DTD_r3_patch_64_bn_8192___AD_window_min                    patch_64
# AE_DTD_r3_patch_64_bn_2048___AD_window_min                    patch_64
# AE_DTD_r3_patch_64_bn_4096___AD_window_min                    patch_64
# AE_DTD_r3_patch_64_bn_256___AD_window_min                     patch_64
# AE_DTD_r3_patch_64_bn_128___AD_window_min                     patch_64
# AE_DTD_r3_patch_64_bn_512___AD_window_min                     patch_64
# AE_DTD_r3_patch_64_bn_1024___AD_window_min                    patch_64
# AE_DTD_r3_patch_128_bn_2048___AD_window_min                  patch_128
# AE_DTD_r3_patch_64_bn_8192___AD_window_mean                   patch_64
# AE_DTD_r3_patch_64_bn_4096___AD_window_max                    patch_64
# AE_DTD_r3_patch_128_bn_8192___AD_window_min                  patch_128
# AE_DTD_r3_patch_64_bn_4096___AD_window_mean                   patch_64
# AE_DTD_r3_patch_64_bn_8192___AD_window_max                    patch_64
# AE_DTD_r3_patch_128_bn_4096___AD_window_min                  patch_128
# AE_DTD_r3_patch_64_bn_2048___AD_window_max                    patch_64
# AE_DTD_r3_patch_64_bn_2048___AD_window_mean                   patch_64
# AE_DTD_r3_patch_64_bn_256___AD_window_mean                    patch_64
# AE_DTD_r3_patch_64_bn_1024___AD_window_mean                   patch_64
# AE_DTD_r3_patch_64_bn_128___AD_window_mean                    patch_64
# AE_DTD_r3_patch_64_bn_512___AD_window_mean                    patch_64
# AE_DTD_r3_patch_64_bn_1024___AD_window_max                    patch_64
# AE_DTD_r3_patch_128_bn_8192___AD_window_mean                 patch_128
# AE_DTD_r3_patch_64_bn_512___AD_window_max                     patch_64
# AE_DTD_r3_patch_128_bn_4096___AD_window_mean                 patch_128
# AE_DTD_r3_patch_128_bn_512___AD_window_min                   patch_128
# AE_DTD_r3_patch_128_bn_2048___AD_window_mean                 patch_128
# AE_DTD_r3_patch_64_bn_256___AD_window_max                     patch_64
# AE_DTD_r3_patch_64_bn_128___AD_window_max                     patch_64
# AE_DTD_r3_patch_128_bn_4096___AD_window_max                  patch_128
# AE_DTD_r3_full_image_128_bn_256___AD_window_max         full_image_128
# ...                                                                ...
# AE_DTD_r3_patch_128_bn_8192___AD_window_max                  patch_128
# AE_DTD_r3_full_image_128_bn_8192___AD_window_max        full_image_128
# AE_DTD_r3_patch_128_bn_1024___AD_window_max                  patch_128
# AE_DTD_r3_full_image_128_bn_512___AD_window_max         full_image_128
# AE_DTD_r3_full_image_128_bn_128___AD_window_max         full_image_128
# AE_DTD_r3_patch_128_bn_512___AD_window_mean                  patch_128
# AE_DTD_r3_full_image_128_bn_4096___AD_window_max        full_image_128
# AE_DTD_r3_full_image_128_bn_2048___AD_window_max        full_image_128
# AE_DTD_r3_full_image_128_bn_8192___AD_window_min        full_image_128
# AE_DTD_r3_patch_128_bn_1024___AD_window_mean                 patch_128
# AE_DTD_r3_full_image_128_bn_4096___AD_window_min        full_image_128
# AE_DTD_r3_full_image_128_bn_1024___AD_window_max        full_image_128
# AE_DTD_r3_full_image_128_bn_2048___AD_window_min        full_image_128
# AE_DTD_r3_patch_128_bn_512___AD_window_max                   patch_128
# AE_DTD_r3_full_image_128_bn_256___AD_window_min         full_image_128
# AE_DTD_r3_patch_128_bn_256___AD_window_mean                  patch_128
# AE_DTD_r3_full_image_128_bn_512___AD_window_min         full_image_128
# AE_DTD_r3_patch_128_bn_128___AD_window_min                   patch_128
# AE_DTD_r3_full_image_128_bn_128___AD_window_min         full_image_128
# AE_DTD_r3_patch_128_bn_128___AD_window_max                   patch_128
# AE_DTD_r3_patch_128_bn_256___AD_window_max                   patch_128
# AE_DTD_r3_full_image_128_bn_256___AD_window_mean        full_image_128
# AE_DTD_r3_full_image_128_bn_8192___AD_window_mean       full_image_128
# AE_DTD_r3_patch_128_bn_128___AD_window_mean                  patch_128
# AE_DTD_r3_full_image_128_bn_1024___AD_window_min        full_image_128
# AE_DTD_r3_full_image_128_bn_4096___AD_window_mean       full_image_128
# AE_DTD_r3_full_image_128_bn_2048___AD_window_mean       full_image_128
# AE_DTD_r3_full_image_128_bn_128___AD_window_mean        full_image_128
# AE_DTD_r3_full_image_128_bn_512___AD_window_mean        full_image_128
# AE_DTD_r3_full_image_128_bn_1024___AD_window_mean       full_image_128
#
#                                                    num_bottleneck  \
# experiment_name
# AE_DTD_r3_patch_64_bn_8192___AD_window_min                 8192.0
# AE_DTD_r3_patch_64_bn_2048___AD_window_min                 2048.0
# AE_DTD_r3_patch_64_bn_4096___AD_window_min                 4096.0
# AE_DTD_r3_patch_64_bn_256___AD_window_min                   256.0
# AE_DTD_r3_patch_64_bn_128___AD_window_min                   128.0
# AE_DTD_r3_patch_64_bn_512___AD_window_min                   512.0
# AE_DTD_r3_patch_64_bn_1024___AD_window_min                 1024.0
# AE_DTD_r3_patch_128_bn_2048___AD_window_min                2048.0
# AE_DTD_r3_patch_64_bn_8192___AD_window_mean                8192.0
# AE_DTD_r3_full_image_128_bn_4096___AD_window_mean  AE_DTD_r3_full_image_128_bn_4096
# AE_DTD_r3_full_image_128_bn_2048___AD_window_mean  AE_DTD_r3_full_image_128_bn_2048
# AE_DTD_r3_full_image_128_bn_128___AD_window_mean    AE_DTD_r3_full_image_128_bn_128
# AE_DTD_r3_full_image_128_bn_512___AD_window_mean    AE_DTD_r3_full_image_128_bn_512
# AE_DTD_r3_full_image_128_bn_1024___AD_window_mean  AE_DTD_r3_full_image_128_bn_1024
#
#                                                   window_aggregation_method
# experiment_name
# AE_DTD_r3_patch_64_bn_8192___AD_window_min                              min
# AE_DTD_r3_patch_64_bn_2048___AD_window_min                              min
# AE_DTD_r3_patch_64_bn_4096___AD_window_min                              min
# AE_DTD_r3_patch_64_bn_256___AD_window_min                               min
# AE_DTD_r3_patch_64_bn_128___AD_window_min                               min
# AE_DTD_r3_patch_64_bn_512___AD_window_min                               min
# AE_DTD_r3_patch_64_bn_1024___AD_window_min                              min
# AE_DTD_r3_patch_128_bn_2048___AD_window_min                             min
# AE_DTD_r3_patch_64_bn_8192___AD_window_mean                            mean
# AE_DTD_r3_patch_64_bn_4096___AD_window_max                              max
# AE_DTD_r3_patch_128_bn_8192___AD_window_min                             min
# AE_DTD_r3_patch_64_bn_4096___AD_window_mean                            mean
# AE_DTD_r3_patch_64_bn_8192___AD_window_max                              max
# AE_DTD_r3_patch_128_bn_4096___AD_window_min                             min
# AE_DTD_r3_patch_64_bn_2048___AD_window_max                              max
# AE_DTD_r3_patch_64_bn_2048___AD_window_mean                            mean
# AE_DTD_r3_patch_64_bn_256___AD_window_mean                             mean
# AE_DTD_r3_patch_64_bn_1024___AD_window_mean                            mean
# AE_DTD_r3_patch_64_bn_128___AD_window_mean                             mean
# AE_DTD_r3_patch_64_bn_512___AD_window_mean                             mean
# AE_DTD_r3_patch_64_bn_1024___AD_window_max                              max
# AE_DTD_r3_patch_128_bn_8192___AD_window_mean                           mean
# AE_DTD_r3_patch_64_bn_512___AD_window_max                               max
# AE_DTD_r3_patch_128_bn_4096___AD_window_mean                           mean
# AE_DTD_r3_patch_128_bn_512___AD_window_min                              min
# AE_DTD_r3_patch_128_bn_2048___AD_window_mean                           mean
# AE_DTD_r3_patch_64_bn_256___AD_window_max                               max
# AE_DTD_r3_patch_64_bn_128___AD_window_max                               max
# AE_DTD_r3_patch_128_bn_4096___AD_window_max                             max
# AE_DTD_r3_full_image_128_bn_256___AD_window_max                         max
# ...                                                                     ...
# AE_DTD_r3_patch_128_bn_8192___AD_window_max                             max
# AE_DTD_r3_full_image_128_bn_8192___AD_window_max                        max
# AE_DTD_r3_patch_128_bn_1024___AD_window_max                             max
# AE_DTD_r3_full_image_128_bn_512___AD_window_max                         max
# AE_DTD_r3_full_image_128_bn_128___AD_window_max                         max
# AE_DTD_r3_patch_128_bn_512___AD_window_mean                            mean
# AE_DTD_r3_full_image_128_bn_4096___AD_window_max                        max
# AE_DTD_r3_full_image_128_bn_2048___AD_window_max                        max
# AE_DTD_r3_full_image_128_bn_8192___AD_window_min                        min
# AE_DTD_r3_patch_128_bn_1024___AD_window_mean                           mean
# AE_DTD_r3_full_image_128_bn_4096___AD_window_min                        min
# AE_DTD_r3_full_image_128_bn_1024___AD_window_max                        max
# AE_DTD_r3_full_image_128_bn_2048___AD_window_min                        min
# AE_DTD_r3_patch_128_bn_512___AD_window_max                              max
# AE_DTD_r3_full_image_128_bn_256___AD_window_min                         min
# AE_DTD_r3_patch_128_bn_256___AD_window_mean                            mean
# AE_DTD_r3_full_image_128_bn_512___AD_window_min                         min
# AE_DTD_r3_patch_128_bn_128___AD_window_min                              min
# AE_DTD_r3_full_image_128_bn_128___AD_window_min                         min
# AE_DTD_r3_patch_128_bn_128___AD_window_max                              max
# AE_DTD_r3_patch_128_bn_256___AD_window_max                              max
# AE_DTD_r3_full_image_128_bn_256___AD_window_mean                       mean
# AE_DTD_r3_full_image_128_bn_8192___AD_window_mean                      mean
# AE_DTD_r3_patch_128_bn_128___AD_window_mean                            mean
# AE_DTD_r3_full_image_128_bn_1024___AD_window_min                        min
# AE_DTD_r3_full_image_128_bn_4096___AD_window_mean                      mean
# AE_DTD_r3_full_image_128_bn_2048___AD_window_mean                      mean
# AE_DTD_r3_full_image_128_bn_128___AD_window_mean                       mean
# AE_DTD_r3_full_image_128_bn_512___AD_window_mean                       mean
# AE_DTD_r3_full_image_128_bn_1024___AD_window_mean                      mean
#
# [63 rows x 11 columns]

# %% [markdown]
# Conclusion:
# * best autoencoder gets 0.698 AUC.
# * best non-probabilistic context_encoder (without ensembling) gets 0.7126
#     * the 128x128 patch, 64x64 mask size gets 0.7095
# * best probabilistic CE without ensembeling gets 0.751
# * best ensembled model gets 0.765

# %% [markdown]
# ### sorted by train experiment
# So that you can compare the effect of window aggregation method

# %%
group = "train_experiment_name"
variable = "window_aggregation_method"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars



data_df = df.pivot(group, variable, y)
yerr_df = df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5))
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %% [markdown]
# Conclusions:
# * min is never best
# * its always mean or max that works best
# * interestingly, mean works better for the gropus that are already good, max better for the groups that aren't good yet.
#
# So let's look at only mean and max, and check out patch and mask size

# %% [markdown]
# ### checking out bottleneck size

# %%
group = "autoencoding_setting"
variable = "num_bottleneck"

filter_variable = "window_aggregation_method"
filter_value = "max"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars


filtered_df = df.loc[df.loc[:,filter_variable] == filter_value,:]
data_df = filtered_df.pivot(group, variable, y)
yerr_df = filtered_df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %%
group = "autoencoding_setting"
variable = "num_bottleneck"

filter_variable = "window_aggregation_method"
filter_value = "mean"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars


filtered_df = df.loc[df.loc[:,filter_variable] == filter_value,:]
data_df = filtered_df.pivot(group, variable, y)
yerr_df = filtered_df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %% [markdown]
# * hmm, not really sure what's going on here.
# * for the patches, too high capacity doesn't seem good
# * for full image, it seems less of a problem

# %% [markdown]
# ### checking out autoencoder setting

# %%
group = "num_bottleneck"
variable = "autoencoding_setting"

filter_variable = "window_aggregation_method"
filter_value = "max"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars


filtered_df = df.loc[df.loc[:,filter_variable] == filter_value,:]
data_df = filtered_df.pivot(group, variable, y)
yerr_df = filtered_df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %%
group = "num_bottleneck"
variable = "autoencoding_setting"

filter_variable = "window_aggregation_method"
filter_value = "mean"

y = "val_mean_aucroc" # all column names that contain this string are plotted
yerr = "val_sem" #  all column names that contain this string are error bars


filtered_df = df.loc[df.loc[:,filter_variable] == filter_value,:]
data_df = filtered_df.pivot(group, variable, y)
yerr_df = filtered_df.pivot(group, variable, yerr)


ax = data_df.plot(kind="bar", yerr=yerr_df, figsize=(15,5), ylim=[0.6,1], title=filter_variable + ": " + filter_value)
ax.set_ylabel(y)
# Out:
# Text(0, 0.5, 'val_mean_aucroc')

# %% [markdown]
# conclusion:
# * ok, now this does seem interesting, I can probably do something with this in the report

# %% [markdown]
# # Mias

# %% [markdown]
# ## augmentations

# %%
experiment_names = [
'r4_CE_Mias_augtest_ctrl_s0',
'r4_CE_Mias_augtest_ctrl_s1',
'r4_CE_Mias_augtest_ctrl_s2',
'r4_CE_Mias_augtest_flip_s0',
'r4_CE_Mias_augtest_flip_s1',
'r4_CE_Mias_augtest_flip_s2',
'r4_CE_Mias_augtest_gamma_1p05_s0',
'r4_CE_Mias_augtest_gamma_1p05_s1',
'r4_CE_Mias_augtest_gamma_1p05_s2',
'r4_CE_Mias_augtest_gamma_1p2_s0',
'r4_CE_Mias_augtest_gamma_1p2_s1',
'r4_CE_Mias_augtest_gamma_1p2_s2',
'r4_CE_Mias_augtest_gamma_1p5_s0',
'r4_CE_Mias_augtest_gamma_1p5_s1',
'r4_CE_Mias_augtest_gamma_1p5_s2',
'r4_CE_Mias_augtest_gamma_2_s0',
'r4_CE_Mias_augtest_gamma_2_s1',
'r4_CE_Mias_augtest_gamma_2_s2',
'r4_CE_Mias_augtest_scale_1p05_s0',
'r4_CE_Mias_augtest_scale_1p05_s1',
'r4_CE_Mias_augtest_scale_1p05_s2',
'r4_CE_Mias_augtest_scale_1p2_s0',
'r4_CE_Mias_augtest_scale_1p2_s1',
'r4_CE_Mias_augtest_scale_1p2_s2',
'r4_CE_Mias_augtest_scale_1p5_s0',
'r4_CE_Mias_augtest_scale_1p5_s1',
'r4_CE_Mias_augtest_scale_1p5_s2',
'r4_CE_Mias_augtest_rot_6_s0',
'r4_CE_Mias_augtest_rot_6_s1',
'r4_CE_Mias_augtest_rot_6_s2',
'r4_CE_Mias_augtest_rot_15_s0',
'r4_CE_Mias_augtest_rot_15_s1',
'r4_CE_Mias_augtest_rot_15_s2',
'r4_CE_Mias_augtest_rot_30_s0',
'r4_CE_Mias_augtest_rot_30_s1',
'r4_CE_Mias_augtest_rot_30_s2',
'r4_CE_Mias_augtest_shear_6_s0',
'r4_CE_Mias_augtest_shear_6_s1',
'r4_CE_Mias_augtest_shear_6_s2',
'r4_CE_Mias_augtest_shear_15_s0',
'r4_CE_Mias_augtest_shear_15_s1',
'r4_CE_Mias_augtest_shear_15_s2',
'r4_CE_Mias_augtest_shear_30_s0',
'r4_CE_Mias_augtest_shear_30_s1',
'r4_CE_Mias_augtest_shear_30_s2',
'r4_CE_Mias_augtest_combo_MLP_s0',
'r4_CE_Mias_augtest_combo_MLP_s1',
'r4_CE_Mias_augtest_combo_MLP_s2',
]


ns = [1]*len(experiment_names)

variables_to_show =  [["loss","map_mse_range11"]]*len(experiment_names)

show_traces_multi_exp(experiment_names = experiment_names, ns=ns, variables_to_show=variables_to_show, logy=False)

# %% [markdown]
# # Working Space

# %%
experiment_names = ["CE_DTD_random_patch_test_1___AD1", "CE_DTD_random_patch_test_1___AD1"]
sort_column = "val_mean_aucroc"

summary_stats_multi_exp(experiment_names, sort_column)
# Out:
#                     experiment_name  val_mean_aucroc    val_sd  \
# 0  CE_DTD_random_patch_test_1___AD1         0.812538  0.132202
# 1  CE_DTD_random_patch_test_1___AD1         0.812538  0.132202
#
#    test_mean_aucroc   test_sd
# 0          0.812538  0.132202
# 1          0.812538  0.132202

# %%
experiment_name = "CE_cpu_dev_test_seeds"
sort_column = "val_mean_aucroc"

n = 2
results_base_dir = "C:\\Users\\MC JB\\msc_project\\mlp_framework\\results"

df = load_summary_file(experiment_name, n, results_base_dir)

# %%
sd = df.groupby(df.index).std().loc[:,"val_loss"]
sd
# Out:
# curr_epoch
# 0    0.0
# 1    0.0
# Name: val_loss, dtype: float64

# %%
experiment_name = "CE_cpu_dev_test_seeds"
sort_column = "val_mean_aucroc"
variables_to_show = "all"

n = 2
results_base_dir = "C:\\Users\\MC JB\\msc_project\\mlp_framework\\results"

show_traces(experiment_name = experiment_name, n=n, variables_to_show=variables_to_show, logy=False)
# Out:
# peak train_loss: 0.3918 in epoch: 1
# peak val_loss: 0.3814 in epoch: 1
